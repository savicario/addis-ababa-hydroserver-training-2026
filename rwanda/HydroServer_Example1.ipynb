# %% [markdown]
# # **Rwanda HydroServer Example 1: Loading Sensor Data for a Monitoring Station**
#
# Code adapted from HydroServer Developers Team: Jeff Horsburgh, Ken Lippold , and Daniel Slaugh
#
# ### **Overview**
#
# This exercise creates a HydroServer workspace, the Kanzenze monitoring site, its stage datastream, and then extracts public RWB field measurements and loads them through a HydroServer ETL pipeline.
#
# Data source: Rwanda Water Resources Board, Kanzenze station 259501.
#
# ### **Description**
#
# This Jupyter Notebook demonstrates how to load time series data for a monitoring site from a comma separate values (CSV) file into a datastream in HydroServer. It demonstrates the following:
#
# 1. Connects to HydroServer
# 2. Creates a Workspace
# 3. Creates a monitoring site (Thing)
# 4. Creates 3 Observed Properties (measured variables)
# 5. Creates 3 Units for the Observed Properties
# 6. Creates a new Sensor
# 7. Creates a new Processing Level
# 8. Creates 3 Datastreams for the Observed Properties
# 9. Loads data from a CSV file into the 3 Datastreams
#
# More detailed examples of how to use hydroserverpy are available in HydroServer's documentation at:
#
# * https://hydroserver2.github.io/hydroserver/user-guides/how-to/using-the-python-client.html
# * https://www.hydroserver.org
#
# ### **Prerequisites**
#
# You must have an account on the HydroServer Playground instance to run this notebook. If you haven't set up your user account yet, navigate to https://playground.hydroserver.org and follow the instructions to create a new user account.
#
# ### **Software Requirements**
#
# This notebook was developed using Python Verion 3.14 and Version 1.9 of the hydroserverpy Python package.

# %% [markdown]
# ## 1. Getting Started
#
# ---

# %% [markdown]
# ### Verify hydroserverpy is installed correctly
#
# The Python environment set up for this workshop already has hydroserverpy version 1.9 installed. If you downloaded this notebook to run locally or you are running in a different JupyterHub environment, you should uncomment the final line in the following code block and run it to ensure that the right version of the hydroserverpy package is installed. The hydroseverpy package version needs to match the version of HydroServer installed on the instance you are connecting to. For this example, we'll be using the Playground instance of HydroServer at [https://playground.hydroserver.org](https://playground.hydroserver.org), which is using Version 1.9.

# %%
# Make sure the correct version of hydroserverpy is installed
# The playground instance of hydroserver is using Version 1.9
# Uncomment and run the following line of code if you need to verify the installation of hydroserverpy
# !pip install hydroserverpy==1.9
# Out:
# Collecting hydroserverpy==1.9
#   Downloading hydroserverpy-1.9.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: requests>=2 in /usr/local/lib/python3.12/dist-packages (from hydroserverpy==1.9) (2.32.4)
# Requirement already satisfied: pydantic>=2.6 in /usr/local/lib/python3.12/dist-packages (from hydroserverpy==1.9) (2.13.4)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.12/dist-packages (from hydroserverpy==1.9) (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.12/dist-packages (from hydroserverpy==1.9) (2.0.2)
# Requirement already satisfied: pyyaml>=5 in /usr/local/lib/python3.12/dist-packages (from hydroserverpy==1.9) (6.0.3)
# Requirement already satisfied: simplejson>=3 in /usr/local/lib/python3.12/dist-packages (from hydroserverpy==1.9) (4.1.1)
# Collecting python-crontab>=3 (from hydroserverpy==1.9)
#   Downloading python_crontab-3.3.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from hydroserverpy==1.9) (2.9.0.post0)
# Collecting croniter>=2.0.1 (from hydroserverpy==1.9)
#   Downloading croniter-6.2.4-py3-none-any.whl.metadata (23 kB)
# Collecting jmespath>=1.0.1 (from hydroserverpy==1.9)
#   Downloading jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->hydroserverpy==1.9) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->hydroserverpy==1.9) (2026.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.6->hydroserverpy==1.9) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.6->hydroserverpy==1.9) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.6->hydroserverpy==1.9) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.6->hydroserverpy==1.9) (0.4.2)
# Collecting email-validator>=2.0.0 (from pydantic[email]>=2.6->hydroserverpy==1.9)
#   Downloading email_validator-2.3.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->hydroserverpy==1.9) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2->hydroserverpy==1.9) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2->hydroserverpy==1.9) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2->hydroserverpy==1.9) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2->hydroserverpy==1.9) (2026.6.17)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->pydantic[email]>=2.6->hydroserverpy==1.9)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading hydroserverpy-1.9.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 kB 4.4 MB/s eta 0:00:00
# Downloading croniter-6.2.4-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 2.7 MB/s eta 0:00:00
# Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading python_crontab-3.3.0-py3-none-any.whl (27 kB)
# Downloading email_validator-2.3.0-py3-none-any.whl (35 kB)
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 16.4 MB/s eta 0:00:00
# Installing collected packages: python-crontab, jmespath, dnspython, email-validator, croniter, hydroserverpy
# Successfully installed croniter-6.2.4 dnspython-2.8.0 email-validator-2.3.0 hydroserverpy-1.9.0 jmespath-1.1.0 python-crontab-3.3.0

# %% [markdown]
# ### Import Required Packages
#
# For this example, we'll use hydroserverpy, pandas, and the datetime packages.

# %%
from hydroserverpy import HydroServer
import pandas as pd
from datetime import datetime
from getpass import getpass

# %% [markdown]
# ### Set the Initial Parameters to Connect to HydroServer
#
# The first step in interacting with a HydroServer instance is to create a connection to that instance. There's two ways to do this:
# 1. You can create a Workspace in the HydroServer Data Management App and then create an API key that allows you to connect to HydroServer using that API key.
# 2. You can use your HydroServer username and password to connect.
#
# For this example, we will use your username and password because we will create the Workspace in code. To use an API key, you must create the Workspace first and then create an API key in the HydroServer Data Management App.
#
# **IMPORTANT: In the following code, change the email to match the HydroServer user account you created.**

# %%
# Set initial parameters to connect to HydroServer
hydroserver_host = 'https://playground.hydroserver.org'

# Change the email and password below to your HydroServer username and password
hydroserver_email = 'svicario@lincolninst.edu' #'user@youremail.com'
hydroserver_password = getpass('Enter your HydroServer password: SARAav1991%') #getpass('Enter your HydroServer password: ')
# Out:
# Enter your HydroServer password: SARAav1991%··········

# %% [markdown]
# ### Initialize HydroServer Connection
#
# Initialize the connection to HydroServer with the connection information specified above.

# %%
# Initialize HydroServer connection with credentials.
hs = HydroServer(
    host=hydroserver_host,
    email=hydroserver_email,
    password=hydroserver_password
)

print('\nSuccessfully connected to HydroServer!')
# Out:
# Successfully connected to HydroServer!

# %% [markdown]
# ### Specify the CSV File to Load Data From
#
# For this example, we are going to load data to a monitoring site we create in HydroServer from a comma-separated values (CSV) file. This CSV file contains raw data for a monitoring station in the Logan River Observatory (LRO) near Logan, UT. This functionality could be used to load data from any CSV file that has a single datetime column and then any number of data columns (e.g., a log file from a field datalogger). To limit the size of the requests we are making to the HydroServer API, we will also specify a chunk size for loading data. We'll load the whole file, but in requests that are sized by the chunk size we set here.

# %%
# Specify the file with data to load and a data chunk size
file_to_load = (
    "https://raw.githubusercontent.com/"
    "savicario/addis-ababa-hydroserver-training-2026/"
    "main/rwanda/data/kanzenze_stage.csv"
)

# Data chunk size to limit data requests through SensorThings API
chunk_size = 10000

# %% [markdown]
# ### Create a Workspace
#
# Now that we are connected to HydroServer, we can create a Workspace for loading some data. The Workspace is an organizing container within which you will create monitoring Sites, Datastreams, and other metadata and content. Access control is also applied at the Workspace level in HydroServer. You can give read-only or edit permission to other HydroServer users to work in your Workspace.
#
# **IMPORTANT**: In the following cell, change the name of the workspace using your name so it is unique to you.

# %%
# Change the workspace name here using your first name so it is unique to you
workspace_name = "Rwanda Training 2026"  # Choose a unique workspace name
new_workspace = hs.workspaces.create(name=workspace_name, is_private=False)

# Get the UUID of the workspace you just created - we'll use it later
workspace_id = new_workspace.uid

# Print some properties of the workspace
print(f"Created workspace named {new_workspace.name}")
print(f"Workspace ID: {workspace_id}")
# Out:
# Created workspace named Rwanda Training 2026
# Workspace ID: 019ff0c6-4a1e-7fa5-ae97-e489da55386f

# %% [markdown]
# ## 2. Set Up Metadata for Loading Data
#
# ---
#
# Now that you have a Workspace, you can create objects and their metadata inside that workspace in preparation for loading data. In the following sections, we will create the necessary metadata to load data for multiple time series of observations for a monitoring site in the LRO. You can create all of this metadata using the web user interface of the Data Management App, or you can do it using code, which we are demonstrating here. Code can make the process faster and more repeatable.
#
# HydroServer uses a modified version of the OGC SensorThings API data model for storing time series data and their associated metadata. HydroServer's data model includes the following important entities that we need to create before loading data:
#
# * **Thing**: A monitoring station on which or at which data were collected (e.g., a streamflow gage or weather station).
# * **Observed Property**: The variable that is measured (e.g., discharge, water temperature, etc.).
# * **Units of Measure**: The units of measure associated with the Observation values (e.g, cubic meters per second).
# * **Sensor**: The instrument or method used to measure or create the Observation values.
# * **Processing Level**: The degree of processing that has been applied to the Observation values (e.g., "Raw" or "Quality Controlled").
# * **Datastream**: A description of the time series that includes all of these attributes.
#
# Once all of these metadata tables have been populated, the time series of data values can be loaded to the **Observations** table in the database.
#
# **NOTE**: To create objects in HydroServer, you will have to pass their required and optional metadata elements. For more information about HydroServer's data model and a data dictionary that describes each of the entities, see HydroServer's documentation at https://www.hydroserver.org.

# %% [markdown]
# ### Create a Monitoring Site (Thing)
#
# First, we'll create a monitoring site. The OGC SensorThings API used by HydroServer calls this a "Thing". We are going to load data for a monitoring site in the Blacksmith Fork River, which is a tributary to Logan River in Utah. So, we need to specify the metadata for the monitoring site we are creating. Once the monitoring site is created, we can access its landing page in HydroServer by building a URL using its UUID.

# %%
# Create a Thing for the Kanzenze Hydrological Station

new_thing = hs.things.create(
    workspace=workspace_id,
    name='Kanzenze Hydrological Station',
    description='Hydrological monitoring station on the Nyabarongo River at Kanzenze, Rwanda.',
    sampling_feature_type='Site',
    sampling_feature_code='259501',
    site_type='Stream',
    latitude='-2.0613',
    longitude='30.0877',
    country='RW',
    data_disclaimer='Data provided by the Rwanda Water Resources Board (RWB).',
    is_private=False
)

# Get the ID for the new Thing and print its HydroServer landing page

thing_id = new_thing.uid

print(f'Created new thing with ID: {thing_id}')
print('You can access the new Thing in the HydroServer Data Management App at:')
print(f'{hydroserver_host}/sites/{thing_id}')

# %% [markdown]
# ### Create Observed Properties
#
# Observed Properties are the variables measured at the monitoring site. Similar to creating the monitoring site (Thing), we need to know the required and optional metadata elements for Observed Properties so we can pass them to the ```create()``` method.
#
# For this example, we will load 3 time series from the CSV file, including disharge, water temperature, and specific conductance, so we need Observed Properties for the 3 columns of data we want to load.

# %%
discharge = hs.observedproperties.create(
    workspace=workspace_id,
    name='Discharge',
    definition='Discharge',
    description='Discharge is the flow rate of water per unit time.',
    observed_property_type='Hydrology',
    code='Discharge'
)
wat_temp = hs.observedproperties.create(
    workspace=workspace_id,
    name='Water Temperature',
    definition='Water Temperature',
    description='Water temperature is the measure of the thermal state of a body of water.',
    observed_property_type='Water quality',
    code='WaterTemp'
)
sp_cond = hs.observedproperties.create(
    workspace=workspace_id,
    name='Specific Conductance',
    definition='Specific Conductance',
    description='Specific conductance is the electrical conductivity of a solution standardized to a reference temperature.',
    observed_property_type='Water quality',
    code='SpCond'
)

print("Created observed properties:")
print(f"{discharge.name}: {discharge.uid}")
print(f"{wat_temp.name}: {wat_temp.uid}")
print(f"{sp_cond.name}: {sp_cond.uid}")

# %% [markdown]
# ### Create Units of Measure
#
# Next we need to add metadata to specify the Units of measure used for recording the data in the CSV file. We need one unit for each of the columns of data we are loading because they are all different.

# %%
discharge_unit = hs.units.create(
    workspace=workspace_id,
    name='Cubic meters per second',
    symbol='m3^s',
    definition='Units for discharge',
    unit_type='Flow rate'
)
wat_temp_unit = hs.units.create(
    workspace=workspace_id,
    name='Degree Celsius',
    symbol='Deg. C',
    definition='Units for temperature',
    unit_type='Temperature'
)
sp_cond_unit = hs.units.create(
    workspace=workspace_id,
    name='Microsiemens per centimeter',
    symbol='uS/cm',
    definition='Units for electrical conductivity',
    unit_type='Electrical Conductivity'
)

print("Created units:")
print(f"{discharge_unit.name}: {discharge_unit.uid}")
print(f"{wat_temp_unit.name}: {wat_temp_unit.uid}")
print(f"{sp_cond_unit.name}: {sp_cond_unit.uid}")

# %% [markdown]
# ### Create Sensors
#
# The OGC SensorThings API data model refers to the method used for creating observations as the "Sensor". In many cases this will be a physical sensor installed at the monitoring site. But, sometimes other methods are used to create observations. Both water temperature and specific conductance were measured using a YSI Multiparameter Water Quality Sonde, but the discharge values for this site are derived from stage measurements made using a pressure transducer. A site-specific rating curve is applied to the stage data to produce the discharge values. So, we need to create the metadata describing this so potential data users know how the data were created.
#
# **NOTE**: The specific metadata required when creating metadata for a Sensor is dependent upon the "Method Type". For instrument deployments, specific information about the manufacturer and model of the sensor should be specified. For "Derivation" methods, the name and description are required, and a method_code and method_link can be specified if needed.

# %%
wq_sensor = hs.sensors.create(
    workspace=workspace_id,
    name='YSI EXO2 Multiparameter Sonde',
    description='YSI EXO2 Multiparameter Sonde',
    encoding_type='json',
    manufacturer='YSI Xylem',
    sensor_model='YSI EXO2',
    sensor_model_link='https://www.ysi.com/exo2',
    method_type='Instrument Deployment',
    method_link='https://www.ysi.com/exo2',
    method_code='USU-EXO2'
)
flow_sensor = hs.sensors.create(
    workspace=workspace_id,
    name='Rating Curve',
    description='Recorded values are derived from observed stage using a site-specific rating curve',
    encoding_type='json',
    method_type='Derivation',
    method_link='https://uwrl.usu.edu/lro/',
    method_code='USU-Discharge'
)

print("Created sensors:")
print(f"{wq_sensor.name}: {wq_sensor.uid}")
print(f"{flow_sensor.name}: {flow_sensor.uid}")

# %% [markdown]
# ### Create a Processing Level
#
# In HydroServer, the Processing Level indicates the degree of processing a datastream has been subject to. For example, data can be "Raw", which means that they were recorded in the field and nobody has looked at them yet, or they could be "Quality Controlled", which means that a technician has reviewed the data. All of the data we are loading right now are raw observations from the field with no processing, so we need a Processing Level that indicates this.

# %%
new_processing_level = hs.processinglevels.create(
    workspace=workspace_id,
    code='Raw',
    definition='Raw Data',
    explanation='Data that have not been processed or quality controlled.'
)

print("Created processing levels:")
print(f"{new_processing_level.code}: {new_processing_level.uid}")

# %% [markdown]
# ### Create Datastreams
#
# The last step before loading data is to create metadata for each of the "Datastreams". This helps us link the time series values to where they were measured, which Observed Property they represent, which Units they are recorded in, etc. In the following code, we create the necessary datastream metadata, using the UUIDs for the other metadata entities we created above for the three datastreams we want to load data to.
#
# **NOTE**: Since these Datastreams are new, they don't contain any Observation values yet. We'll set the ```value_count=0``` and arbitrarily set the ```phenomenon_begin_time``` and ```phenomenon_end_time```. Those will get reset when we load Observation values. All of the LRO aquatic sensor data have spacing of 15-minutes, so we set that accordingly. Each Datastream has a name and description that we'll set using some attributes of the Datastream, but you can name these accoding to your own naming conventions.

# %%
ds_discharge = hs.datastreams.create(
    name=f"{discharge.name} measured in the {new_thing.name}",
    description=f'{discharge.name} created using a {flow_sensor.name}',
    thing=new_thing.uid,
    sensor=flow_sensor.uid,
    observed_property=discharge.uid,
    processing_level=new_processing_level.uid,
    unit=discharge_unit.uid,
    observation_type='Field Observation',
    result_type='Timeseries',
    sampled_medium='Liquid aqueous',
    no_data_value=-9999,
    aggregation_statistic='Continuous',
    time_aggregation_interval=0,
    time_aggregation_interval_unit='minutes',
    intended_time_spacing=15,
    intended_time_spacing_unit='minutes',
    status='Ongoing',
    value_count=0,
    phenomenon_begin_time=datetime(year=2024, month=1, day=1),
    phenomenon_end_time=None,
    result_begin_time=datetime(year=2024, month=1, day=1),
    result_end_time=None,
    is_private=False,
    is_visible=True
)
ds_wat_temp = hs.datastreams.create(
    name=f"{wat_temp.name} measured in the {new_thing.name}",
    description=f'Measured using a {wq_sensor.name}',
    thing=new_thing.uid,
    sensor=wq_sensor.uid,
    observed_property=wat_temp.uid,
    processing_level=new_processing_level.uid,
    unit=wat_temp_unit.uid,
    observation_type='Field Observation',
    result_type='Timeseries',
    sampled_medium='Liquid aqueous',
    no_data_value=-9999,
    aggregation_statistic='Continuous',
    time_aggregation_interval=0,
    time_aggregation_interval_unit='minutes',
    intended_time_spacing=15,
    intended_time_spacing_unit='minutes',
    status='Ongoing',
    value_count=0,
    phenomenon_begin_time=datetime(year=2024, month=1, day=1),
    phenomenon_end_time=None,
    result_begin_time=datetime(year=2024, month=1, day=1),
    result_end_time=None,
    is_private=False,
    is_visible=True
)
ds_sp_cond = hs.datastreams.create(
    name=f"{sp_cond.name} measured in the {new_thing.name}",
    description=f'Measured using a {wq_sensor.name}',
    thing=new_thing.uid,
    sensor=wq_sensor.uid,
    observed_property=sp_cond.uid,
    processing_level=new_processing_level.uid,
    unit=sp_cond_unit.uid,
    observation_type='Field Observation',
    result_type='Timeseries',
    sampled_medium='Liquid aqueous',
    no_data_value=-9999,
    aggregation_statistic='Continuous',
    time_aggregation_interval=0,
    time_aggregation_interval_unit='minutes',
    intended_time_spacing=15,
    intended_time_spacing_unit='minutes',
    status='Ongoing',
    value_count=0,
    phenomenon_begin_time=datetime(year=2024, month=1, day=1),
    phenomenon_end_time=None,
    result_begin_time=datetime(year=2024, month=1, day=1),
    result_end_time=None,
    is_private=False,
    is_visible=True
)

print("Created datastreams:")
print(f"{ds_discharge.name}: {ds_discharge.uid}")
print(f"{ds_wat_temp.name}: {ds_wat_temp.uid}")
print(f"{ds_sp_cond.name}: {ds_sp_cond.uid}")

# %% [markdown]
# ## 3. Load Time Series Data from the CSV File
#
# ---
#
# Now that we have all of the metadata we need, we can read the CSV data file and load data. The following sections break this down using a convenience data structure for mapping the names of the columns in the CSV file to the datastreams they represent and then chunking up the CSV data to load it into HydroServer. The UUIDs for the datastreams come from the datastreams we just created in the last step.

# %% [markdown]
# ### Create Datastream UUID Mapping to CSV File Columns
#
#  We'll first create a convenience data structure (a Python List object) to match up the column names in the CSV file with the UUIDs of the Datastreams we need to load their data into. We'll use this to specify which columns from the file we want to load. Each element in the Python list will be a Tuple specifying the name of the column in the CSV file and the UUID for the datastream the values in that column should be loaded into.
#
# **NOTE**: The datastream metadata must exist in HydroServer before loading data into it. You must have one entry in this list for each CSV column/datastream to be loaded into the database.

# %%
# Datastream tuple: (CSV DataFileColumnName, HydroServer Datastream_UUID)
datastreams = [
    ('Discharge_cms', ds_discharge.uid),
    ('WaterTemp_EXO', ds_wat_temp.uid),
    ('SpCond', ds_sp_cond.uid)
]

print(f"Number of datastreams to load: {len(datastreams)}")

# %% [markdown]
# ### Read the CSV File Using Pandas
#
# Read the CSV file containing data to load using Pandas. Skip comment rows in the header that don't contain data or column headings and also parse the dates in the LocalDateTime and DateTimeUTC columns to ensure that we datetime objects instead of strings in the resulting Pandas dataframe.

# %%
# Read the CSV data file containing data to load.
df = pd.read_csv(
    file_to_load,
    sep=',',
    comment='#',
    header=0,
    parse_dates=[0,2],
    low_memory=False
)

print('Data file read successfully.')
print(f"Number of rows in CSV file to be loaded: {len(df)}")

# %% [markdown]
# ### Specify the Time Zone for the Data
#
# LRO datalogger timestamps are recorded in Mountain Standard Time (UTCOffset = -7 hours). If no timezone offset information is provided when loading data, HydroServer will assume the timestamps you provide are in UTC. The data file we are loading data from already has a DateTimeUTC column, but the fact that it is UTC is not encoded in the file. So, we need to tell Pandas that those timestamps are UTC before loading the data.

# %%
# Tell Pandas that the timestamps in the "DateTimeUTC" column are actually UTC
df['DateTimeUTC'] = df['DateTimeUTC'].dt.tz_localize('UTC')

print('Data file now contains UTC timestamps in the "DateTimeUTC" column.')

# %% [markdown]
# ### Chunk the Data and Load into HydroServer
#
# The last step in loading data is to divide it up into reasonably sized chunks to load it into HydroServer. We set the chunk size (the number of records to add at one time) at the top of this notebook. The code below just divides the Pandas dataframe up into chunks for each datastream according to the chunk size and then loads the data one chunk at a time using the hydroserverpy ```load_observations()``` function.

# %%
# Loop through datastreams in the list and load data from the CSV file
for datastream in datastreams:
    # Subset the original dataframe to isolate the current time series to load
    column_name = datastream[0]
    observations = df[['DateTimeUTC', column_name]]
    # Rename columns to 'phenomenon_time' and 'result' as expected by hydroserverpy
    observations = observations.rename(columns={'DateTimeUTC':'phenomenon_time', column_name:'result'})

    # Get the datastream into which the data will be loaded
    datastream_id = datastream[1]
    datastream = hs.datastreams.get(uid=datastream_id)

    # Upload the observations to the datastream in HydroServer
    if len(observations) > chunk_size: # Load the observations one chunk at a time
        # Split the dataframe into chunks of rows < chunk_size
        chunks = [observations.iloc[i:i+chunk_size] for i in range(0, len(observations), chunk_size)]

        # Iterate through each subset (chunk) of rows
        for idx, chunk in enumerate(chunks):
            # Load the observations in the chunk
            datastream.load_observations(chunk)
            # Print progress
            print(f"Loaded chunk {idx + 1} with {len(chunk)} {column_name} observations for datastream={datastream_id}")

    else:  # Load all observations at once
        datastream.load_observations(observations)

    # Print progress
    print(f"\nLoaded {len(observations)} {column_name} observations into datastream={datastream_id}\n")

print('Done loading data!')
print(f"Access the data in HydroServer at: {hydroserver_host}/sites/{thing_id}")

# %% [markdown]
# ## Summary
#
# Now you know the general patterns for how to create a workspace in HydroServer and then how to create metadata and then load data into HydroServer from a CSV file using hydroserverpy.
